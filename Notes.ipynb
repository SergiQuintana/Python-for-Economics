# %% [markdown]
# # Python for Economists:
#
# Notes created by Sergi Quintana Garcia for the course Python Brush Up in Economics.
#
# ## Table of Content:
# 1.[Why do people use Python?](#whypython)</br>
# 2.[What is Python used for?](#whatfor)</br>
#
# Python is a free and open-source programming language that was created in 1989 by a Dutch programmer Guido van Rossum. Since then, it has experienced a rapid adoption, becoming one of the most used languages nowadays. According to the 2022 Stack Overflow Developer Survey, which explore the tools and technologies developers are currently using, Python is the fourth most popular language among professionals, and the third among people learning to code. https://jupyterbook.org/en/stable/content/myst.html
#
# |![PythonRanking.png](attachment:840acd30-9d17-46d0-82b3-8b173aa12926.png)|
# |:--:|
# |*Programming Languages Popularity in 2022. Source: 2022 Stack Overflow Developer Survey.*|
#
# ## Why do people use Python? <a name="whypython"></a>
#
# As we have seen, Python is clearly one of the most used programming languages. Given the large amount of programming languages available today, the natural question is what is the reason behind its popularity? According to Mark Lutz, Python expert and writer of the best-seller book “Learning Python”, the most common reasons are:
#
# <ul>
# <li><b> Software Quality: </b></li> Python code is designed to be readable, which makes it simple and easy-to-learn.
#     <li><b> Developer Productivity: </b></li> Python code takes fewer lines than other languages. For example, Python code is typically one-third to one-fifth the size of equivalent C++ or Java code. This basically means you can write it faster increasing productivity.
# <li><b> Support Libraries: </b></li>Python comes with a large collection of prebuilt functionalities, known as the standard library. However, if those are not enough, Python can be expanded with a large number of frameworks and libraries.
# <li><b> Program Portability: </b></li>Most of the programs run unchanged on multiple platforms like Windows, macOS or Linux.
# <li><b> Component Integration: </b></li> Python can be easliy used together with other programming languages. It can invoke languages like C or C++.
# </ul>
#
# ## What is Python used for? <a name="whatfor"></a>
#
# But, what for? Python is widely use in fields like communications, web development, data analysis, machine learning, game development, security and more. In particular, python is used in multiple companies and institutions such as Google, YouTube, Dropbox, NSA, Spotify and others. The next figure shows BLABLABLA
#
# |![PythonUse.png](attachment:66bb4f51-6127-4b14-adc7-733d081c6aab.png)|
# |:--:|
# |*Use of Python among users. Source: JetBrains Development Ecosystem Survey 2021* |
#
# ## A revision about programming languages.
# Python is an open source general-purpose programming language, which is defined as an object-oriented scripting language. But, what do all those concepts mean? Before getting into what python is, let’s have a review about programming languages. Official site: https://www.python.org/doc/essays/blurb/
#
# According to Wikipedia a programming language is a system of notation for writing computer programs. Most programming languages are text-based forma languages, but they might also be graphical.  Furthermore, a computer program is a sequence or set of instructions for a computer to execute. Each programming language has its own syntax. That is, its way of writing the instructions.
#
# ### <ins> Types of Programming Languages </ins>
#
# Programming languages can be classified according to different criteria. Those are some:
# <ul>
#     <li> <b> Level</b></li>The level of a language refers to the amount of abstraction the language provides from a computer’s instruction set architecture.  There are two levels:
#     <ul>
#         <li><ins> Low-level Languages :</ins> Programming languages with very little or no abstraction from a computer’s instruction set architecture. This refers to machine code or assembly language. Given this low level of abstraction this class of languages are described as being “close to the hardware”.  These languages are hard to learn and very time-consuming. </li>
#         <li><ins> High-level Languages :</ins>Programming languages that have been developed to make it easier for programmers to read and write programs. Usually, they use English expressions to make the code more understandable. Examples are C,C++, Python, Java and others, although some provides more level of abstraction than others. For example, C and C++ are sometimes called middle-level languages since there is less abstraction than for example in Python.</li>
#     </ul>
#     An example would be to take a look at how Fibonacci numbers are in different languages: <br><br>
#     <ins> Machine code </ins>
#     <blockquote>8B542408 83FA0077 06B80000 0000C383 FA027706 B8010000 00C353BB <br>
# 01000000 B9010000 008D0419 83FA0376 078BD98B C84AEBF1 5BC3</blockquote>
#     <ins> Assembler  </ins>
#      <blockquote>ib: mov edx, [esp+8] cmp edx, 0 ja @f mov eax, 0 ret @@: cmp edx, 2 ja @f <br>
# mov eax, 1 ret @@: push ebx mov ebx, 1 mov ecx, 1 @@: lea eax, 3 jbe @f mov <br>
# ebx, ecx [ebx+ecx] cmp edx, mov ecx, eax dec edx jmp @b @@: pop ebx ret
# </blockquote>
#     <ins> C++ </ins>
#      <blockquote><pre>int fibonacci(const int x) { <br>
#         if (x==0) return(0);<br>
#         if (x==1) return(1);<br>
#         return (fibonacci(x-1))+fibonacci(x-2);}</pre>
# </blockquote>
#
# <li><b> Domain </b></li> The domain is the targeted subject area of a computer program. Examples of domains can be accounting, e-commerce, numerical mathematics, cloud computing and much more. There are two types of classifications according to the domain:
# <ul>
#     <li><ins> General-purpose Programming Languages (GPL):</ins> is a language that is applicable across application domains and lacks specialized features for a particular domain. Examples are Fortran, Python, C, C++ and others.  The main advantage is that they are more powerful and usually faster to run. </li>
#     <li><ins> Domain Specific Languages:</ins> Is a language specialized to a particular application domain.  Examples are Julia, R, Matlab and others. The main advantage is that they are easier to learn, faster to code, and have a lot of built-in functions and procedures. </li>
#     </ul>
#     <li><b> Execution</b></li>
#     The execution specifies the behavior of the elements of the language. There are different types:
#     <ul>
#     <li><ins>Compiled:</ins> A compiled language translates the code written on the language into another language to obtain the desired output. The main language is a high-level language that is translated into a lower level language to create an executable program. Examples are Fortran or C/C++. </li>
#     <li><ins>Interpreted:</ins> An interpreted language directly executes the instructions wihtout the need of compile it into another language first. Examples are Python,R or Mathematica.
#     <li><ins>Just-in-time Compiled:</ins> It is a way of executing a language in which the code is compiled during the execution. Examples are Julia and Matlab. </li>
#     </ul>
#     <li><b> Paradigm </b></li>
#     It is a way of classifying languages based on their features. Languages can be classified into multiple paradigms. Common language paradigms include:
#     <ul>
#     <li><ins>Imperative:</ins> The programmer instructst the machine how to change state. Examples are <b>procedural</b> which group instructions into a procedure or <b>object-oriented</b> which is based on the conpect of objects that can contain data and code.
#     <li><ins>Declarative:</ins> The programmer only declares properties of the desired result. Examples are logic, functional or mathematical. </li>
# </ul>
#
# ## Python technical part (or how python runs programs)
#
# The first important concept is the Python interpreter. It is the software in charge of reading and executing the instructions of our programs. In order to run a Python code we must have the interpreter installed in our computer.  See installation HERE. How does it work? The user would type code into text files and those files would run throgh the interpreter. But what is the interpreter doing? Let's take a look!
#
# The first thing that Python does when we execute a program is to translate the instructions of our file into byte code. Basically, the interpreter translates the Python language into a lower-level lenguage and creates a compiled file that Python will store. This will save us execution time, because if in the future we execute the code again, Python will use the compiled version and skip the compilation.
#
# Once the code is translated into byte code it is taken into the runtime engine of Python, known as the Python Virtual Machine (PVM). The PVM iterates over the byte code instructions one by one to carry the instructions and produce the desired output.
#
# |![pythonruntime.png](attachment:59e34d2d-1530-4886-b003-6dc13168662b.png)|
# |:--:|
# |*Python Runtime Structure. Source: "Learning Python. 5th Edition,Mark Lutz"*
#
# Remember also, that this is performed by Python internally hidden from users. Programmers simply have to write code and run files to obtain the desired output. For those interested in this topic, consider reading Chapter 2 from the book *Learning Python* from *Mark Lutz*.
#
# <b>IF I HAVE TIME INCLUDE MORE FROM MY BOOK </b>
#
# ---
# ## Getting Started
#
# As we have seen in the introduction, Python is an object-oriented programming language. This means that objects are the most fundamental notion of Python programming. Everything is an object in Python, from a number to very elaborated data structures. Python provides a powerful set of built-in objects that make programs easy to write, are more efficient than other data structures and are part of the language. For this reason, let's start by reviewing Python built-in object types.
#
# | Object Type | Example |
# | ------------|---------|
# | Numbers  | 765, 7.87, Decimal()|
# | Strings  | 'Python', "Hi!", "3", str()|
# | Lists | [1,2,3],[3,['dog',24]], list(range(9))|
# | Dictionaries | {'name':'Jhon','age':'22'},dict(hours=10)|
# | Tuples | (2,"apple",5,'Z') |
# | Files | open('cars.txt') |
# | Sets | set('abc'),{'a','b','c'} |
# | Other core types | Booleans,types,None |
# | Program unit types | Functions, modules, classes|
#
# The previous table shows the different object types with examples. Let's briefly describe what the different objects are:
#
# #### Numbers
# Python provides different built-in numbers which are enough to represent most numeric quantities. However, those can be expanded by third-party packages if needed. There are three numeric types in Python:
#     <ul>
#         <li>Integers: Numbers withouht a fractional part.</li>
#         <li>Floats : Numbers with fracional parts </li>
#         <li>Complex : Numbers with imaginary parts </li>
#     </ul>
#     Some examples are:

# %%
myint = 3 #integer
myfloat = 2.3 #float
mycomplx = 3j #complex

print(type(myint))
print(type(myfloat))
print(type(mycomplx))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> We are using <b> functions </b> in the previous code.
#      <ul>
#          <li> Notice we can use the function <b>type()</b> to verify the type of any object in Python. </li>
#          <li> We can also use the function <b> print() </b> to display the specified message in the screen.</li> </div>
# <b> Conversion </b>
# Types can also be converted to one or another using the *int()*,*float()* or *complex()* functions.

# %%
# Let's now try it!

x = 3 #integer
y = float(x) # float
print(type(y))


z = 2.5 #float
c = complex(z) #complex
print(type(c))


# However, there are conversions that are not possible without losing information:
e = 2.3 #float
w = int(e)
print(type(w))
print(w)
# Out:
# <class 'float'>
# <class 'complex'>
# <class 'int'>
# 2

# %% [markdown]
# Python also supports the standard mathematical opperations. Some examples are:

# %%
print(12 + 35) #integer addition
print(34.2 * 5) #floating-point multiplication
print(2**100) #2 to the power of 100

# We can also work with numerical objects
x = 3
y = 2.5
print(x**y)
# Out:
# 47
# 171.0
# 1267650600228229401496703205376
# 15.588457268119896

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> We can use Python <b> modules </b> that will help us work with numbers. Modules are packages of additional tools. Some examples are:
#     <ul>
#         <li> <b> math :</b> Contains advanced numeric tools like functions. </li>
#         <li> <b> random :</b> Performs random-number generation and random selections.
#              </li> </div>

# %%
import math
print(math.pi)
print(math.sqrt(34))
# Out:
# 3.141592653589793
# 5.830951894845301

# %%
import random
print(random.random())
print(random.choice([1,2,3,4,5]))
# Out:
# 0.5513345808421128
# 2

# %% [markdown]
# #### Strings
# The next type of objects are strings. They are used to collect both textual information and arbitrary collection of bytes. To denote a string we can either use quotation marks or double quotation marks.

# %%
print("hello")
print('hello')
# Out:
# hello
# hello

# %%
#we can also assign a string value to a variable
myname = 'Sergi'
print(myname)
# Out:
# Sergi

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> Strings are considered  <b> sequences. </b> - a positionally ordered collection of other objects. Sequences mantain left-to-right order among the items they contain. In that sense, strings are sequences of one-character strings. Other sequences are lists or tuples. </div>
#
# Since strings are considered *sequences* we can verify their length and index their elements.

# %%
myname = "Sergi"
print(len(myname))    # The length of the sequence of one-character strings

print(myname[0])    #The first element of the string sequence
print(myname[1])    # Second element
# Out:
# 5
# S
# e

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> Python <b> indexing. </b> starts at "0". This means that the first element of the sequence is 0, the second is 1 and so on. </div>
#
# We have just seen how Python indexing works. Let's review some of it's applications. In Python, it is possible to index backwards, form the end- positive indexes count from the left, negative index count back from the right. An example is:

# %%
myname = 'Sergi'

print(myname[-1])              #Last item from the string stored in myname
print(myname[len(myname)-1])   #The hard way of obtaining the last item.

# We can also get the second-to-last item

print(myname[-2])
# Out:
# i
# i
# g

# %% [markdown]
# Sequences can also support a more general way of indexing, which is knonw as *slicing*. This allows to extract an entire section (or slice) in a single step. An example is:

# %%
print(myname[1:3])   # Slice the second and third elements.
# Out:
# er

# %% [markdown]
# Notice that when *slicing* the first number denotes the first element that should be included and the second number denotes the first element that should *not* be included. For this reason, if we slice *myname*[1:3] this will return a slice contaning elements with index 1 and 2. There are other *slicing* properties:

# %%
print(myname[1:])     # Everything past the first element. 
print(myname[:-1])    # Everything but the last element. 
print(myname[:])      # Everything
# Out:
# ergi
# Serg
# Sergi

# %% [markdown]
# #### String Operations and Methods
#
# The most basic `string` operations are concatenation and repetition.

# %%
myname = 'Sergi'  

# CONCATENATION:

print(myname+'Quintana')    # Concatenate two strings.

surname = 'Quintana'       
fullname = myname+surname  # It works with two variables two!
print(fullname)

fullname = myname + ' '+surname # to include a space
print(fullname)

print(myname,surname)      # Notice we can also print two elements, so there is no need for concatenation

# REPETITION:

print(myname*3)    # Repeat myname 3 times

repeatname = fullname*2
print(repeatname)
# Out:
# SergiQuintana
# SergiQuintana
# Sergi Quintana
# Sergi Quintana
# SergiSergiSergi
# Sergi QuintanaSergi Quintana

# %% [markdown]
# Another way to assign values to variables is by using the funciton `input()` which allows to interact with the user. An example is:

# %%
name = input()
print(name)
# Out:
#  hello
# hello

# %% [markdown]
# Strings have attached type specific methods. Those are functions specific so string-type objects which are triggered with a call expression. Some of those are:
# <ul>
#     <li> <b> Find </b>: It returns the index of the first occurrence in a string or -1 if it is not present.</li>
#     <li> <b> Replace </b>: Replaces occurreces of a string with another. </li>
#     <li> <b> Upper </b>: Changes all the letters to uppercase. </li>
#     <li> <b> Lower </b>: Changes all the letters to lowercase. </li>
#     <li> <b> Capitalize </b>: Puts the first letter in uppercase </li>
#     <li> <b> Title </b> : Puts the first letter of every word in uppercase </li>
#     <li> <b> Swapcase </b>: Swaps upper letters for lower letters and vice versa </li>
#     <li> <b> Strip </b> : Eliminate all the spaces at the beging and at the end of a string. </li>
#     <li> <b> Split </b>: Divides an string into a list of strings </li>
# </ul>
# Let's see them in practise!

# %%
# Find
name = 'Sergi'
print(name.find('e'))   # Returns the index of the first occurrence of "e"
print(name.find('o'))   # Returns -1 since 'o' does not occur. 

# Notice we can also specify the range at which we would like to find

print(name.find('e',2,4)) # Returns -1 since on that range there is no 'e'.
# Out:
# 1
# -1
# -1

# %%
# Replace

x = 'Hello Marta'
print(x.replace('a','XXX'))       # We can replace a single character
print(x.replace('Marta','Jhon'))  # Or we can also replace mutiple characters.

y = x.replace('Hello','Hi')    # We can also asign the result to a new variable
print(y)

# We can also specify how many occurrences of the old value we want to replace.

print(x.replace('a','XXXX',1)) # We are just replacing the first 'a'.
# Out:
# Hello MXXXrtXXX
# Hello Jhon
# Hi Marta
# Hello MXXXXrta

# %%
# Uppper

x = 'sergi'
print(x.upper())   # no need to introduce any argument

y = 'Sergi'
print(y.upper())   # it does not matter if there were already upper letters.

# Lower (same idea as upper)

print(y.lower()) 
z = 'SERGI'
print(z.lower())
# Out:
# SERGI
# SERGI
# sergi
# sergi

# %%
# Capitalize

name = 'sergi'
print(name.capitalize())   # does not take any argument

# Title
string = 'my name is sergi'
print(string.title())
# Out:
# Sergi
# My Name Is Sergi

# %%
# Swapcase

string = 'ApPle'
print(string.swapcase()) 

# Strip

text = ' apple  '     # notice there are spaces
print(text)
print(text.strip())  # removes the spaces
# Out:
# aPpLE
#  apple
# apple

# %%
# Split

text = 'My name is Sergi'
print(text.split())     # If no argment is provided, it will split based on spaces
print(text.split('e'))  # We can decide based on which string we would like to split
print(text.split('a')) 
print(text.split('e',1)) # Furthermore, we can choose the maximum amount of splits we would like
# Out:
# ['My', 'name', 'is', 'Sergi']
# ['My nam', ' is S', 'rgi']
# ['My n', 'me is Sergi']
# ['My nam', ' is Sergi']

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> It is possible to apply <b> multiple </b> methods at once. An example is: </div>

# %%
text = 'this is an appple'
print(text.upper().split('I'))
# Out:
# ['TH', 'S ', 'S AN APPPLE']

# %% [markdown]
# We have just seen some of the possible methods we can use with *strings*.  If we want to see all the possible methods that we can apply we can use the built-in function `dir()`. For the purpose of this course, we do not care about methods with double underscores.

# %%
a = 'string'
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %% [markdown]
# #### Lists
#
# The Python list is the most general *sequence* provided by the language. With a list, one can store multiple elements inside one variable.  They are the most flexible tool to represent arbitrary collections.  Furthermore, contrary to *strings*, lists are mutable, which means we can change their elements in place.

# %%
# Lists

list1 = ['apple']     # a list can have only one element
print(type(list1))

list2 = ['apple','orange']   # it can also have multiple elements.
print(type(list2))

list3 = [1,2,3]    #It can be made of numbers
print(type(list3))


list4 = [1,'orange',2334] # and also of combinations of numbers and strings
print(type(list4)) 


list5 = [list1, list2, list3, list4]  # Finally, we can have lists made of lists. 
print(list5)
print(type(list5))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# [['apple'], ['apple', 'orange'], [1, 2, 3], [1, 'orange', 2334]]
# <class 'list'>

# %% [markdown]
# Since lists are sequences they support all the sequence opperations discussed for strings. Those are for example indexing or slicing, among others.

# %%
my_list = [1,'hi','dog']
print(len(my_list))      # we can check the length

print(my_list[0])   # we can index 

print(my_list[1:])   # and also slice

# Also, we can access the elements of the list. 
print(my_list[1][1])  # since my_list[1] returns 'hi', we can then use [1] to obtain the 'i' from 'hi.

print(my_list+['Jordi',23])  # Concatenation is also possible

print(my_list*3)   # Repetition
# Out:
# 3
# 1
# ['hi', 'dog']
# i
# [1, 'hi', 'dog', 'Jordi', 23]
# [1, 'hi', 'dog', 1, 'hi', 'dog', 1, 'hi', 'dog']

# %% [markdown]
# Notice we can also create lists directly from strings:

# %%
text = 'apple'
my_list = list(text)
print(my_list)
# Out:
# ['a', 'p', 'p', 'l', 'e']

# %% [markdown]
# For list composed of numbers we can find the maximum and minimum elements. Also, if the list is only composed by strings we can find the same based on alfabetic order.

# %%
numbers = [1,23,45,3,24]
print(max(numbers))
print(min(numbers))

text = ['hi','apple','orange']
print(max(text))
print(min(text))
# Out:
# 45
# 1
# orange
# apple

# %%
# Notice that if the list is composed of both numbers and strings the operation
# is no longer possible. 

lista = [1,'apple',23]
print(max(lista))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7524\3934447995.py in <module>
#       3
#       4 lista = [1,'apple',23]
# ----> 5 print(max(lista))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# #### Methods for Lists
# Some of the most used methods are:
# <ul>
#     <li> <b> Copy </b>: Allows to copy a particular list </li>
#     <li> <b> Clear </b>: Assigns an empty list to a particular list. </li>
#     <li> <b> Count </b>: Count the amount of times an element appears on a list. </li>
#     <li> <b> Reverse </b>: Reverses the order of the elements in the list </li>
#     <li> <b> Sort </b>: Sorts the elements of the list according to numeric or alphabetical order. Only possible when all the elements of the list are of the same type. </li>
#     <li> <b> Remove </b>: Allows to remove a specific element from a list based on it's value </li>
#     <li> <b> Pop </b>: Removes a specific element from a list based on it's index </li>
#     <li> <b> Append </b>: Adds an item to the end of a list. </li>
#     <li> <b> Extend </b>: Adds all the elements of an interable (list, string, tuple) to the end of a list.</li>
# </ul>

# %%
# COPY

text = ['book','laptop','green']
newlist = text.copy()      # no argument needed
print(newlist)
# Out:
# ['book', 'laptop', 'green']

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> Important information about why <b> copy </b> is a usefull method. </div>

# %%
# CLEAR 

text = ['book','laptop','green']
text.clear()
print(text)

# COUNT

text = ['book','laptop','green','book','orange']
print(text.count('book'))      #counts the amount of times 'book' appears on the list.
# Out:
# []
# 2

# %%
# REVERSE
text = ['book','laptop','green','book','orange']
text.reverse()    # this reverses the list, and references it to the variable text. 
print(text)

# SORT
text.sort()     # Will sort the elements of the list. 
print(text)
# Out:
# ['orange', 'book', 'green', 'laptop', 'book']
# ['book', 'book', 'green', 'laptop', 'orange']

# %%
importance about reverse and clear methods...
# Out:
#   File "C:\Users\Sergi\AppData\Local\Temp\ipykernel_7524\2100566470.py", line 1
#     importance about reverse and clear methods...
#                ^
# SyntaxError: invalid syntax

# %%
# REMOVE
text = ['book','laptop','green','book','orange']
text.remove('book')
print(text)   # If a list contains duplicated elements, it will only remove the first. 

# POP
text.pop(3)    # using the 3 index (4rd element)
print(text)
# Out:
# ['laptop', 'green', 'book', 'orange']
# ['laptop', 'green', 'book']

# %%
# APPEND
text = ['book','laptop','green','book','orange']
text.append('house')
print(text)        # adds an element to the end

# EXTEND
text2 = ['beach','ball','water']
text.extend(text2)   # includes all the elements

print(text)

text2.extend('sun')     # since it includes the iterable items, this will include each character
print(text2)
# Out:
# ['book', 'laptop', 'green', 'book', 'orange', 'house']
# ['book', 'laptop', 'green', 'book', 'orange', 'house', 'beach', 'ball', 'water']
# ['beach', 'ball', 'water', 's', 'u', 'n']

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> Some <b> methods </b> will not return anything. Does it mean they don't do anything? No! It is just that the object they return will be none. </div>
#
# For example, the method `reverse()` will actually reverse the list. However, it does not create a new object. On the other hand, the method `copy()` does create a new object. See an example:

# %%
# If we try to asing the value of reverse() to a new object, the result is none

text = ['book','laptop','green','book','orange']
print(text.reverse())

# The same happens with clear or sort
print(text.clear())
print(text.sort())
# Out:
# None
# None
# None

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> Note about Python variable creation. A variable in Python is created when in the code we first asign a value to it. Variables are just names that reference particular objects. For example, when we create a variable <b> a = 3 </b> Python is doing the following:
# <ol>
#     <li> Create an object to represent the value of 3.</li>
#     <li> Create the variable <b> a </b> if it does not exist yet </li>
#     <li> Link the variable <b>a</b> to the new object 3. </li>
#     </ol>
# It is very important to understand that variables always link to objects and never to other variables. In that sense, links from variables to objects are called references.
# </div>
#
# On the previous box Python variable creation is discussed. The reason to do that is to understand what happens when to variables point to the same object, and to justify the need of methods like `copy()`. At first sight the reader might think that the copy() method is useless since we can just create a new variable equal to the past one.

# %%
# Example
text = ['book','laptop','green','book','orange']
text2 = text 
print(text2)
# Out:
# ['book', 'laptop', 'green', 'book', 'orange']

# %% [markdown]
# However, by asigning `text2 = text` all we are doing is referencing the new variable `text2` to the already existing object `['book','laptop','green','book','orange']`. What are the implications of this? If we produce any change in the variable `text2` it will also change the variable `text` since they are pointing to the same object.
#
# |![shared_reference.png]|
# |:--:|
# |*Python Shared Reference. Source: Fig 6.2. from Learing Python by Mark Lutz.*|

# %%
text2[2] = 'House'  # replace the 3rd element of text2. 
print(text)         # The element also changes in text! 

# For this reason we use copy()
text = ['book','laptop','green','book','orange']
text2 = text.copy()

text2[2] = 'House'

print(text)
print(text2)
# Out:
# ['book', 'laptop', 'House', 'book', 'orange']
# ['book', 'laptop', 'green', 'book', 'orange']
# ['book', 'laptop', 'House', 'book', 'orange']

# %% [markdown]
# By using the method `copy()` we are creating a new object in the memory of Python, and we can safely chaning withouht accidentally changing the initial object.

# %% [markdown]
# #### Dictionaries
# Python dictionaries are knonw as *mappings*. Mappings are collections of objects that are stored by their *key* instead of by their relative position. Each *value* of a dictionary has an asociated *key*.  In a dictionary, both the *key* and the *value* can be of any type.

# %%
first_dicc  = {'name': 'Jhon', 'surname':'Smith'}  #first element key, second value

print(first_dicc)

mydict = {1:'house',23:'flat'}  #keys are numbers, values are strings
print(mydict) 

mydict = {2:'door','number':34} # mixt of types
print(mydict)

mydict = {'names':['Jhon','Angela'], 'age':[13,18]}   #we can even do a dict with a list
print(mydict)

# We can also create dictionaries using other ways:
bob1 = dict(name='Bob',job='dev',age=40)
print(bob1)

bob2 = dict(zip(['name','job','age'],['Bob','dev',40]))
print(bob2)
# Out:
# {'name': 'Jhon', 'surname': 'Smith'}
# {1: 'house', 23: 'flat'}
# {2: 'door', 'number': 34}
# {'names': ['Jhon', 'Angela'], 'age': [13, 18]}
# {'name': 'Bob', 'job': 'dev', 'age': 40}
# {'name': 'Bob', 'job': 'dev', 'age': 40}

# %% [markdown]
# #### Methods and opperations
#
# We will now review the most common methods and opperations with dictionaries. Some of the methods are:
# <ul>
#     <li> <b> Get </b>: Returns a value based on a key.</li>
#     <li> <b> Keys</b>: Will return a list of all the keys in the dictionary.</li>
#     <li> <b> Values </b>: Will return a list of all the values in the dictionary. </li>
#     <li> <b> Items </b>: Will return each item in the dictionary as tuples on a list. </li>
#     <li> <b> Update </b>: Will change the value of a key, or introduce a new key and value if the key did not exist before. </li>
#     <li> <b> Pop </b>: Like with lists, it will eliminate the item with a specific key.  </li>
#     <li> <b> Clear </b>: Empties the dictionary.</li>

# %%
# GET
bob1 = dict(name='Bob',job='dev',age=40)
print(bob1.get('name'))

# KEYS
print(bob1.keys())

#VALUES
print(bob1.values())

#ITEMS
print(bob1.items())
# Out:
# Bob
# dict_keys(['name', 'job', 'age'])
# dict_values(['Bob', 'dev', 40])
# dict_items([('name', 'Bob'), ('job', 'dev'), ('age', 40)])

# %%
#UPDATE

bob1.update({'name':'Jhon'})    #change an already exisiting key
print(bob1)

bob1.update({'married':'Yes'}) # include a new item
print(bob1)

# the same can be done by indexing:

bob1['name'] = 'Albert'  # change an already existing key
print(bob1)

bob1['kids'] = 2    # include a new item
print(bob1)
# Out:
# {'name': 'Jhon', 'job': 'dev', 'age': 40}
# {'name': 'Jhon', 'job': 'dev', 'age': 40, 'married': 'Yes'}
# {'name': 'Albert', 'job': 'dev', 'age': 40, 'married': 'Yes'}
# {'name': 'Albert', 'job': 'dev', 'age': 40, 'married': 'Yes', 'kids': 2}

# %%
#POP
bob1.pop('name')   # delete one item
print(bob1)

# CLEAR
bob1.clear()
print(bob1)
# Out:
# {'job': 'dev', 'age': 40, 'married': 'Yes', 'kids': 2}
# {}

# %% [markdown]
# #### Tuples
#
# Tuples are lists that cannot be changed. They are also *sequences* but as opposite of lists, they are *inmutable*. They do suport aribtrary types,like lists.

# %%
# Tuples

t = (1,'house','car')
print(t)
print(type(t))

# We can do concatenation: 
print(t+(1,2,3))

# Idexing and slicing
print(t[1])
print(t[2:])
# Out:
# (1, 'house', 'car')
# <class 'tuple'>
# (1, 'house', 'car', 1, 2, 3)
# house
# ('car',)

# %% [markdown]
# A tuple can also be created from a list.

# %%
mylist = [1,2,'hi']

t = tuple(mylist)   # transform the list into a tuple
print(t)
print(type(t))    # now it is a tuple

t2 = (mylist,2)   # and we can even create a tuple of lists. 
print(type(t2))
# Out:
# (1, 2, 'hi')
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# #### Methods and Operations

# %% [markdown]
# First of all notice that indexation still works with tuples. Also, the most common methods are:
# <ul>
#     <li> <b> Count </b>: Returns the number of times an element appears. </li>
#     <li> <b> Index </b>: Returns the index of a particular element.  </li>
#     <li> <b> </b>: </li>
#     EXAMPLES ABOUT UNPACKING https://www.w3schools.com/python/python_tuples_unpack.asp

# %% [markdown]
# #### Sets
#
# Sets are collections of data used to store multiple items into a single variable. The main difference with lists and tuples is that sets are inmutable, unordered and therefore unindexed. Another peculiarity of sets is that they do not allow duplicated values. Furthermore, they can be of any type and can contain different data types.

# %%
# Sets
myset = {1,2,'house'}
print(type(myset))

myset = {1,2,'house',1}   # introduce repeated elements
print(myset)              # they are just ingored


# Add elements:

myset.add('car')     # add elements using the add() method. 
print(myset)

# Add multiple items:
myset2 = {1,'green','beach'}

myset.update(myset2)  # add another set using the update() method.
print(myset)          # repeated elements are just ignored.
# Out:
# <class 'set'>
# {1, 2, 'house'}
# {1, 2, 'car', 'house'}
# {1, 2, 'beach', 'house', 'green', 'car'}

# %%
INTRODUCE SETS PROPERTIES AND METHODS LIKE UNITION, INTERSECTION, ETC!!!!
# Out:
#   File "C:\Users\Sergi\AppData\Local\Temp\ipykernel_7524\22091741.py", line 1
#     INTRODUCE SETS PROPERTIES AND METHODS LIKE UNITION, INTERSECTION, ETC!!!!
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Booleans
#
# The last object type that we will see here are booleans. Booleans can only have two values, either `True` or `False`. Booleans can be created by atributing a value, but they are often the result of some logic comparisons. Let's see some examples:

# %%
# Booleans 

boolean = False        # This boolean is a False
print(type(boolean))   # The type is boolean
print(boolean)         # The stored value is just False
# Out:
# <class 'bool'>
# False

# %%
# Logic Comparisons

# Suppose we have some variables:

age_maria = 39
age_paul = 5

print(age_maria>age_paul)  # The result of this comparison is a Boolean
print(age_maria == age_paul) 

check = age_maria >age_paul  # it can be stored into a new variable
print(check)
# Out:
# True
# False
# True

# %% [markdown]
# The most basic comparisons are equal, greater or smaller than. However, there are other types of logic comparisions one could do. In the next section we will review those operations

# %% [markdown]
# ### If Statements, Loops, List Comprerhension and Functions

# %% [markdown]
# ##### Comparisons
#
# As we have just seen, the most fundamental comparisons are equal, greater or smaller than. However, there are others:

# %%
# Greater or Equal

print(4>=4)   # Check wether 4 is greater or equal than 4.

# Not Equal

print(4 != 3)   # Check wether 4 is different from 3

# In

list1 = [1,2,3,'car']

print(1 in list1)     # we can check if an element belongs to a list. 
print(1 not in list1) # or if it does not belong to it
# Out:
# True
# True
# True
# False

# %% [markdown]
# ##### If Statements
# The `if` statement is the main statement used for selection from alternative actions based on test results. If the condition being tested is equal to true, then the alternative is chosen. If the condition is false, then the code is not executed.

# %%
# If conditon
if 4>3 : 
    print('Hello World!')   # When the condition is satisfied the code is executed. 
    
if 4>5:
    print('My car is blue!') # When the condition is not satisfied, the code is not executed. 
    
# It can be also done with lists

years = [1995,1996,1997,1998]

if 1997 in years:   # Check if the year belongs to the list years. 
    print('Great!')
# Out:
# Hello World!
# Great!

# %% [markdown]
# We have just seen the most basic `if` condition, in which no alternative option is specified. However, most of the time we would like to perform an alternative option when the `if` condition is not satisfied. Those are known as the `else`conditions.

# %%
# Example:

if 4>5: 
    print('Good!')
else:  # acconts for when the if condition is not satisfied. 
    print('Bad!')
# Out:
# Bad!

# %% [markdown]
# Furthermore, we might one to specify more than one `if` statement. For this reason we can use the `elif` statement.

# %%
x = 'Jhon'
if x == 'Peter':
    print('Go Home!')
elif x == 'Jhon':
    print('Welcome!')
else: 
    print('Who are you?')
# Out:
# Welcome!

# %% [markdown]
# ###### Nested If Conditions
#
# We can also have an `if` statement inside another `if` statement.

# %%
if 3>2:
    if 2>1:
        print('Cool')
# Out:
# Cool

# %% [markdown]
# And we can also have `if` statements based on mutiple conditoins. The syntaxt is the following:

# %%
if (4>3) and (5>4):
    print('works')
    
# Check the boolean counterpart

print((4>3) and (5>4))
print(4>3 and 5>4)      # Notice the bracket is not important
print(4>3 & 5>4)        # The and is very important, never use &
# Out:
# works
# True
# True
# False
# False

# %% [markdown]
# Notice than in Python there is a difference between `and` and `&`. The first one is a logical operator that returns `True` when both conditions are satisfied. The later is a bitwise operation that acts on bits and performs bit-by-bit operations. Nothing that we would actually want to do. When using `a & b` Python is doing the bitwise opeartion `a x b`, for this reason the former example was returned as a false.  For the `or` logical operator we would have to use `or` instead of the bitwise operator `|`.

# %%
# Check using the or operator

if 3>4 or 5>2:
    print('Correct!')
# Out:
# Correct!

# %%
EXERCICE FOR IF CONDITOINS https://www.geeksforgeeks.org/check-multiple-conditions-in-if-statement-python/

# %% [markdown]
# In Python we can also use logical conditions when we are willing to declare a variable.

# %%
A = 't' if 3>4 else 'f'    # Since the first condition is not met, the second is applied
print(A)
# Out:
# f

# %% [markdown]
# #### while and for Loops
#
# Loops are statements that repeat some action over and over. As with other programing languages, the main two types of loops are `while` and `for` loops. Whlie the `while` loop provides a way to code general loops, the `for` statement is designed for stepping through the items in a sequence or other iterable object.
#
# ###### while Loops
#
# It is the most general itereation construct in the language. The idea is that it repeatedly executes a block of statements as long as some condition is evaluated as `True`.  The syntaxt is the following:

# %%
#while loop

n= 0
while n <3:
    print(f'Iteration number {n}')
    n+=1          # we are summing one number to n
    
x = 'Hello'
while x:          # While x is true. 
    print(x,end=' ')
    x=x[1:]       # Strip first character off x
# Out:
# Iteration number 0
# Iteration number 1
# Iteration number 2
# Hello ello llo lo o

# %% [markdown]
# We have learned some things in the previous example. First of all, when we want to add a number to a variable we just need to use the syntaxt `var+=1`. This will add one. It can be also used to add wathever amount we would like. Furthermore, we have seen we can introduce as a logical condition just one variable. This is because all Python variables are `True`, apart from 0 and empty variables. See some examples:

# %%
# True conditions
print(bool(1))
print(bool('house'))   
# False Conditions 
print(bool(0))
# Out:
# True
# True
# False

# %%
# example adding 10
n = 0
while n <50:
    print(f'iteration {n}')
    n +=10
# Out:
# iteration 0
# iteration 10
# iteration 20
# iteration 30
# iteration 40

# %%
# We can also have interactive while loops

check = False    # Specify the condition
while check == False:    
    
    age = int(input('Please input your age:'))
    
    if age < 21:
        
        print('You are not allowed to drink')
        
    else:
        print('You are allowed to drink!')
        check = True
# Out:
# Please input your age: 18
# You are not allowed to drink
# Please input your age: 22
# You are allowed to drink!

# %% [markdown]
# ## break, continue, pass and the Loop else
# Let's now introduce some statements that have a purpose only when nested inside loops. Those statements are:
# <ul>
#     <li> <b> break </b>: Jumps out of the closest enclosing loop (past the entire loop statement) </li>
#     <li> <b> continue </b>: Jumps to thhe top of the closest enclosing loop (to the loop's header line) </li>
#     <li> <b> pass </b> : Does nothing at all: it's an empty statement placeholder </li>
#     <li> <b>  Loop else block </b>: Runs if and only if the loop is exited normally (i.e. without hitting a break) </li>
# </ul>
#
# ### pass
#
# The `pass` statement is a no-operation placeholder that is used when the syntaxt requires an statement, but you have nothing useful to say. It is often used to code an empty body for a compound statement. For example, we could code an inifinite loop that does nothing:

# %%
while True: pass  #type Ctr-C to stop!
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7524\2307692631.py in <module>
# ----> 1 while True: pass  #type Ctr-C to stop!
#
# KeyboardInterrupt:

# %% [markdown]
# `pass`might make more sense in more advanced settings, since the previous example is not really very usefyll.
#
# #### continue
#
# The `continue` statement causes an immediate jump to the top of a loop. It can be used to avoid statement nesting or for example to avoid odd numbers.

# %% [markdown]
# # Example 1
# n = 0
# while n<3:
#     n+=1
#     print('a',end= ' ')
#     continue       # The loop goes back to the top.
#     print('hi')    # This part of the code is never executed

# %%
# Example 2
x=10
while x:   # Remember 0 is False
    x-=1
    if x%2 != 0 : continue  # check if the number is odd, then skip. 
    print(x,end=' ')
# Out:
# 8 6 4 2 0

# %%
# The same can be obtained without continue:
x = 10
while x:
    x-=1 
    if x %2 == 0:
        print(x,end=' ')
# Out:
# 8 6 4 2 0

# %% [markdown]
# #### break
#
# The `break` statement causes an inmediate exit from a loop. Because the code that follows it in the loop is not executed if the `break` is reached, you can sometimes avoid nesting by including a `break`.

# %%
 # example break:
n = 0
while n < 10:
    print('hi!')
    print(n)
    n+=1
    if n == 4: break
# Out:
# hi!
# 0
# hi!
# 1
# hi!
# 2
# hi!
# 3

# %%
# Interactive break loop:
while True:
    name = input('Enter Name')
    if name == 'stop': 
        print('Exit Completed') 
        break
    age = input('Enter Age')
    print("Hi, I'm ",name,"and I'm ",age)
# Out:
# Enter Name stop
# Exit Completed

# %% [markdown]
# #### Loop else
#
# It is combined with the `break` statement. It will appear after the body of the loop and will be executed when the interations are done unless we hit a `break`.

# %%
# Example prime numbers
x=10
while x>1:
    print(x)
    if x == 3:     #play with this condition
        print('Forced stop')
        break
    x-=1
    
else:
    print('Done!')
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# Forced stop

# %% [markdown]
# #### for Loops
# The for loop is a generic iterator in Python: it can step through the items in any ordered sequence or other iterable objects. It can iterate on *strings,lists,tuples* and other built-in iterables. It's syntaxt begins with a header line that specifies an assignment target, along iwth the object you want to step through. It looks like:
# ```
# for target in object:
#     statements
# ```
# When Python runs a `for` loop, it assings the item in the iterable `object` to the `target` one by one and executes the loop body for each. The loop body tipically uses the assignment target to refer to the current item in the sequence.

# %%
# example:

for item in ['house','car','orange']:
    print(f'The current item is: {item}')
# Out:
# The current item is: house
# The current item is: car
# The current item is: orange

# %%
# Notice that how you call the target is irrelevant:
for apple in ['house','car','orange']:
    print(f'The current item is: {apple}')
# Out:
# The current item is: house
# The current item is: car
# The current item is: orange

# %%
# We can also iterate over strings
for character in 'house':
    print(character)
# Out:
# h
# o
# u
# s
# e

# %%
# usually it looks like
objects = ['pen','laptop','knife']
for obj in objects:
    print(obj)
    
# other ways are:
for i in range(len(objects)):   # range from 0 to len(objects)=3
    obj = objects[i]            # select the object that corresponds to that index
    print(i,obj)                  # print its value
# Out:
# pen
# laptop
# knife
# 0 pen
# 1 laptop
# 2 knife

# %% [markdown]
# The `for` statement also supports an optional else block, which works exactly as it does with `while` loops.

# %%
# Example:
for obj in objects:
    print(obj)
    if obj == 'bike': break
else:
    print('no more objects')
# Out:
# pen
# laptop
# knife
# no more objects

# %% [markdown]
# ##### Tuple assignemnt in for loops
#
# If you're interating through a sequence of tuples, the loop target itself can actually be *tuple* of targets. See example:

# %%
# Example
T = [(1,'a'),('hi',23),(4,5)]
for (a,b) in T:
    print(a)
    print (f'This is {b}')
# Out:
# 1
# This is a
# hi
# This is 23
# 4
# This is 5

# %%
# We can also iterate on both items together:
for a in T:
    print(a)
# Out:
# (1, 'a')
# ('hi', 23)
# (4, 5)

# %%
# and we can do an unpacking
for a in T:
    a1,a2 = a
    print(a1)
    print(a2)
# Out:
# 1
# a
# hi
# 23
# 4
# 5

# %% [markdown]
# We can also iterate over `dictionaries`.

# %%
mydict = {'name':'Jhon','age':18,'city':'Barcelona'}

# we are only printing keys
for key in mydict:
    print(f'{key} is a key!')
# Out:
# name is a key!
# age is a key!
# city is a key!

# %%
# we can also obtain both key and value

for key in mydict:
    print(f'{key} is a key!')
    print(f'{mydict[key]} is a value!')
# Out:
# name is a key!
# Jhon is a value!
# age is a key!
# 18 is a value!
# city is a key!
# Barcelona is a value!

# %%
# another way is:
for key, value in mydict.items():   # using the item() method!
    print(f'{key} is a key!')
    print(f'{value} is a value!')
# Out:
# name is a key!
# Jhon is a value!
# age is a key!
# 18 is a value!
# city is a key!
# Barcelona is a value!

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TIP!</b> We can use the function <b> range </b> to loop over sequences of numbers. Let's see some examples: </div>

# %%
for number in range(4,10):
    print(number,end=' ')
# Out:
# 4 5 6 7 8 9

# %%
for number in range(100,150,3):
    print(number,end=' ')
# Out:
# 100 103 106 109 112 115 118 121 124 127 130 133 136 139 142 145 148

# %%
for number in range(100,50,-2):
    print(number,end=' ')
# Out:
# 100 98 96 94 92 90 88 86 84 82 80 78 76 74 72 70 68 66 64 62 60 58 56 54 52

# %% [markdown]
# ### List Comprehension
#
# The list comprehensions is an advanced operation which turns out  to be a powerful way to process list structures. It is a way of slicing lists based on logic operators. List comprehensions are very elegenat and their use is always encouraged. Let's see an example:

# %%
# Example with a list of lists: 
M = [[1,2,3],[4,5,6],[7,8,9]]   # a list of lists (similar to a matrix)

# Suppose we would like to extract the first row. We can just do
print(M[0])

# However, what if we want to extract the second column?

print([row[1] for row in M])    # We can use a list comprehension!
# Out:
# [1, 2, 3]
# [2, 5, 8]

# %% [markdown]
# List comperhensions derive from set notation; they are a way to build a new lst by running an expression on each item in a sequence, one at a time, from left to right. List comperhensions are coded in squared brackets (to signal that they make a list) and are copmised of an expression and a looping construct that share a variable name (*row* in our example). We can have more complex examples:

# %%
print([row[1] for row in M if row[1] % 2 == 0])   # filter out odd items
# Out:
# [2, 8]

# %% [markdown]
# List comperhensions make new list of results, but they can be used to iterate over any iterable object. For instances in the next example we use list comprehensions to step over a hardcoded list of coordinates:

# %%
diag = [M[i][i] for  i in range(3)]   # take the diagonal elements
print(diag)
# Out:
# [1, 5, 9]

# %%
# Another example is to classify odd and even numbers in the range of 10

print([[num,'even'] if num % 2 != 0 else [num,'odd'] for num in range(1,11)])
# Out:
# [[1, 'even'], [2, 'odd'], [3, 'even'], [4, 'odd'], [5, 'even'], [6, 'odd'], [7, 'even'], [8, 'odd'], [9, 'even'], [10, 'odd']]

# %% [markdown]
# We can also introduce two loops in a list comperhension. For example to eliminate one dimension from our list:

# %%
# Back to the matrix M
M = [[1,2,3],[4,5,6],[7,8,9]]

print([num for row in M for num in row])   # we are eliminating one dimension!
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# EXERCICE:
# Create a list of the squared terms for the mutiples of 3 between 1 and 100
print([(num,num**2) for num in range(1,100) if num % 3 == 0])
# Out:
# [(3, 9), (6, 36), (9, 81), (12, 144), (15, 225), (18, 324), (21, 441), (24, 576), (27, 729), (30, 900), (33, 1089), (36, 1296), (39, 1521), (42, 1764), (45, 2025), (48, 2304), (51, 2601), (54, 2916), (57, 3249), (60, 3600), (63, 3969), (66, 4356), (69, 4761), (72, 5184), (75, 5625), (78, 6084), (81, 6561), (84, 7056), (87, 7569), (90, 8100), (93, 8649), (96, 9216), (99, 9801)]

# %% [markdown]
# ### Functions
# Functions are a nearly universal program-structuring device. You may have come across them before in other languages. Functions serve two primary development roles:
# <ul>
#     <li> <b> Maximizing code reuse and minimizing redundancy </b>: Functions are the simplest way to packge logic you ay want to use in more than one place and more than one time. Functions allow to group and generalize code to be used arbitrarily many times later. </li>
#     <li> <b> Procedural decomposition </b>: Functions also provide a tool for splitting systems into pieces that have well-defined roles.</li>
# </ul>
# The main concepts behing Python functions are:
# <ul>
#     <li> <b> def is executable code </b>: Python functions are written with a new statement, the  <b> def</b>. Unlike other languages, the function does not exist until the executable reaches and runs the <b> def </b>. For this reason, we cannot call functions that have not been defined yet. </li>
#     <li> <b> def creates an object and assings to it a name </b>: When Python reaches and runs a <b> def </b> statement, it generates a new funcion object and assigns it to the functoin's name.
#     <li> <b> lambda creates an object but returns it as a reuslt </b>: Functions may also be created with the <b> lambda </b> expression, a feature that allows to define in-line function definitions in places where a <b> def </b> statement won't work. </li>
# </ul>
#
# Function syntaxt is the following:
# |![functions.png](attachment:eda7e7c3-32a3-4236-bb27-edc517dd64f1.png)|
# |:--:|
# |* Python Functions syntaxt. Source: learnbyexample.org *|
#
# From a function perpesctive we have that:
# <ul>
#     <li> <b> Arguments </b> : Value sent to the function when it is called. </li>
#     <li> <b> Parameters </b>:  Variable listed in the parenthesis of the function definition.</li>

# %%
# Example:
def myname(name):
    print(f'My name is {name}')
    
myname('Jhon')   # Jhon --> Argment, name---> Parameter
# Out:
# My name is Jhon

# %%
# In Python we can write functions with no arguments:

def number2():
    print(2)
    
number2()
# Out:
# 2

# %%
# Example of a function with one argument:

def function1(name):
    if len(name) < 7:
        check = [i for i in name]
    else:
        check = 'Name too long'
    return check

print(function1('Jhon'))
print(function1('Avocado'))
# Out:
# ['J', 'h', 'o', 'n']
# Name too long

# %%
# Example of a function with two arguments:
def function2(num1,num2):
    result = num1 + num2 + num1*num2
    return result

print(function2(1,3))

# We can improve it by checking the type of the arguments

def function3(num1,num2):
    if type(num1) == int and type(num2) == int:
        result = num1 + num2 + num1*num2
        return result       # imporatnt return must be deifined here, otherwise the function will not work!!!
    else:   
        print('Invalid Argument')
    

function3(4,3)
function3('sergi',4)
# Out:
# 7
# Invalid Argument

# %% [markdown]
# #### Keywords
#
# In Python, we can be more specific about what goes where when we call a function. Keyword arguments alloq us to match by <b> name </b> , instead of by position. Let's see an example:

# %%
# Keywords

def func4(a,b,c):
    print(a)
    print(b+c)
    return a+b+c

# Under positional arguments we would do:
func4(1,2,3)

# However, we can match according to the name:
 
func4(b=1,c=5,a=10)   # notice now the argument for the parameter a is provided in the third place, but it is not a problem!
# Out:
# 1
# 5
# 10
# 6
# 16

# %% [markdown]
# The `a=10` in this example means send `10` to the argument named `a`. Notice then that the left-to-right order does not matter when keyqords are used because arguments are matched by name, not by position. It is even possible to combine positional and keyword arguments at the same time:

# %%
func4(3,c=10,b=2)
# Out:
# 3
# 12
# 15

# %% [markdown]
# When most people see this the first time, they woder why one would use such a tool. Keywords typucally have two roles in Python. First, they makey your calls a bit more self-documenting. For example in a function line `func(name='Bob',age=40)` it is more understendable than `func('Bob',40)`. The second major use of keywords occurs in conjuction with defaults, which we turn to next.
#
# #### Defaults
#
# Defaults will allow us to make selected function arguments optional: if not passed a value, the argument is assigned its default before the function runs. Let's see how it works:

# %%
def func5(a,b,c=10):
    return a+b+c
print(func5(1,2))     # the function takes 3 arguments, but only 2 are mandatory
print(func5(1,2,20))  # We can also change the default value of the optional argument.
# Out:
# 13
# 23

# %% [markdown]
# The interaction of keywords and defaults occur when there is more than one default argument, because it allows us to skip arguments, which is something not possible with  positional arguments.

# %%
def func6(a,b=3,c=10):
    return a+b+c

func6(1,c=20)  # we can skip b, which is in 2nd positon, and move directly to c.
# Out:
# 24

# %% [markdown]
# Notice default values are usally used when we want some features of our function to be locked by default. For example:

# %%
def func7(a,b,c,prod=False):
    print(a+b+c)
    if prod == True:
        print(a*b*c)

func7(1,3,3)
func7(1,3,3,True)
# Out:
# 7
# 7
# 9

# %% [markdown]
# #### Arbitrary Arguments
#
# Suppose the number of arguments that will be passed to the function is unknown. Then we can use `*args` or `**kwargs`.
# The term `*args` will allow the function to recieve an arbitrary number of positional arguments, and access them accordingly. Suppose for example we would like to sum the income of different individuals, but the total amount of individuals might differ.  We can then do:

# %%
# Examople:
def sum_income(*individuals):
    print(f'Total Amount of Individuals is {len(individuals)}')
    print(f'Total Income is {sum(individuals)}')
    return sum(individuals)
          
income = sum_income(3,4,5,5,6,78)
# Out:
# Total Amount of Individuals is 6
# Total Income is 101

# %%
# We can also pass a list, as long as we include *

incomes = [2,3,4,5,6,7,234]

sum_income(*incomes)   # See what happens if * is removed!
# Out:
# Total Amount of Individuals is 7
# Total Income is 261
# 261

# %% [markdown]
# The natural extension of `*args` are `**kwargs`. Suppose we are creating a function but we do not know how many key word arguments will be added to the function. To deal with that we use `**kwargs`. Here the function will recieve a dictionary of arguments and will access them accordingly. This will allow the function to recieve an aribitrary number of keword arguments and access them accordingly. In a sense, the `**` form allos you to convert from keywords to dictionaries, which you can then step though with *keys* calls, dictionary iterators and others.

# %%
def func8(**kwargs):    # Most basic kwargs function. 
    print(kwargs)
func8(a=1,b=3,name='Jhon')
# Out:
# {'a': 1, 'b': 3, 'name': 'Jhon'}

# %% [markdown]
# There are other ways of using kwargs

# %%
def func9(**kwargs):
    
    for key, value in kwargs.items():
        print("{} is {}".format(key,value))
        
func9(name='Jhon',age=55,city='Barcelona')   # We can give an arbitrary number of keyword arguments. 
func9(Color='blue',Number=51)
# Out:
# name is Jhon
# age is 55
# city is Barcelona
# Color is blue
# Number is 51

# %% [markdown]
# #### *args and *kwargs
#
# Finally, function headers can combine normal arguments, the `*` and the `**` to implement widly flexible call signatures. For instance, in the following example, `1` is passed to `a` by position, `2` and `3` are collected into `args` positional tuple, and `x` and `y` wind up in the `kwargs` dictironary:

# %%
def func10(a,*args,**kwargs):
    print(a,args,kwargs)
    
func10(1,2,3,x=1,y=2)
# Out:
# 1 (2, 3) {'x': 1, 'y': 2}

# %% [markdown]
# The previous code is rare, but shows up in functions that need to support multiple call patterns.

# %%
EXERCICE!! EMULATE THE PRINT FUNCTION, PAGE 568!!!
# Out:
#   File "C:\Users\Sergi\AppData\Local\Temp\ipykernel_7524\1366140018.py", line 1
#     EXERCICE!! EMULATE THE PRINT FUNCTION, PAGE 568!!!
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Functions can call other functoins
#
# We have already seen this since most of our previous examples where using the `print()` function. However, let's see an example:

# %%
def func11(a,b):
    result = a+b
    test  = a>b
    print(f'Test if a >b : {test}')
    return result

def func12(a,b):
    result = func11(a,b)
    print(f'This is the result: {result}')

func12(2,3)
# Out:
# Test if a >b : False
# This is the result: 5

# %% [markdown]
# And functions can even call themselves. This type of constructions are called <b> recursive </b> functions. Following there is an example of a recursive function to find the factorial of an integer.

# %%
def factorial(x):
    
    if x == 1:
        return 1
    else:
        return (x*factorial(x-1))
    
num=25
print('The factorial of', num,'is',factorial(num))
# Out:
# The factorial of 25 is 15511210043330985984000000

# %% [markdown]
# Function recursion makes the code look elegant and clear and allows complex task to be broken down into simpler sub-problems..

# %% [markdown]
# #### Functions with multiple outcomes.
#
# Python functions can also return multiple outcomes. The user can then choose how many of the outcomes is willing to get.

# %%
# Example:
def func13(a,b):
    result1 = a+b
    result2= a*b
    return result1,result2

result1 = func13(1,2)          # Only get one outcome
reulst1,result2 = func13(3,4)  # Get both outcomes

# %% [markdown]
# ### Anonymous Functions: lambda
# Beside the `def` statement, Python also provides an expression form that generates function objects. Like `def`, this expression creates a function to be called later, but it returns the function instead of assigning it to a name. This is why `lambdas` are sometimes known as anonymous functions. The syntaxt is `lambda arguments : expression`. Let's see an example.

# %%
lambda1 = lambda a: a+2       # lambda function with one argument
print(lambda1(3))

lambda2 = lambda a,b : a+b   # lambda function with two arguments
print(lambda2(2,4))
# Out:
# 5
# 6

# %% [markdown]
# `lambda` functions can take any number of arguments, but can only have one expression. For now we will see simple examples, but the true power of lambda functions will be seen when dealing with Data Frames, since `lambda` can appear in places a `def` is noyt allowed by Python.
#
# One of the peculiarities of `lambdas` is that they can be used inside a function definition creating a quite powerful tool. Let's see an example:

# %%
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)   # we can now create an object which is the lambda function for n=2

print(mydoubler(11))

mytriple = myfunc(3)   # but we can do it as well for n=3

print(mytriple(3))
# Out:
# 22
# 9

# %%
INTRODUCE MORE EXAMPLES WITH LAMBDA FUNCTIONS !!!
# Out:
#   File "C:\Users\Sergi\AppData\Local\Temp\ipykernel_7524\3390988271.py", line 1
#     INTRODUCE MORE EXAMPLES WITH LAMBDA FUNCTIONS !!!
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Class
#
# So far we've been using the term 'object' generically. Really, the code written up to this point has been *object-based* -we've passed objects around our scrips, used them in expressions, called their methods, and so on. For our code to be truly *object-oriented* our objects will generaly need to also participate in something called *inheritance hierarchy*, a concept that will be explained later in this section.
#
# A `class` is a coding structure and device that is used to impement new kinds of objects in Python that suport inheritance. Classes are Python main object-oriented programming tool. As you'll see, the objects defined with classes can look a lot like the built-in types we studied earlier. The main properties of Python classes are:
# <ul>
#     <li> <b> class statement </b>: It creates the object and assigns it a name. The class is the object that contains all the information. </li>
#     <li> <b> class attributes </b>: Attributes of a class record state information and behavior shared by all the instances created from the class. Class attributes can by accesed by: `object.name`.
#     <li> <b> class methods </b>: Methods are the diferent instances or functions we can apply to our different classes </li>.
# </ul>
#
# In the following part of the chapter we will learn how to create a class, establish it's attributes and finally apply some methods.
#
# #### Class and Attributes
# Tho create a `class` we just need to use the same syntaxt as with functions, but now using the `class` statement. Once a `class` is created, we would need to specify what are its attibutes. Those will be the properties and characteristics that will shape our class. To establish the attributes we will use the `__init__` method, which is known as the constructor method and is used to initialize objects state. Furthermore, to define the parameters of the class, we will use the `self` statement, that will allow to access the parameterst that belong to the class. The attributes defined in `__init__` are known as instance attributes.  Let's take a look:

# %%
# Let's create a class:

class Person:                # define the class
    
    def __init__(self,name,age,city):  # create the method that will define its attributes
        
        self.name = name               # set the class characteristics
        self.age = age
        self.city = city
        
jhon = Person('Jhon',34,'Barcelona')   # create a new object called jhon with the class characteristics. 
jhon.name
# Out:
# 'Jhon'

# %% [markdown]
# We can also check all the attributes at the same time by using the built-in method `__dict_`.

# %%
jhon.__dict__
# Out:
# {'name': 'Jhon', 'age': 34, 'city': 'Barcelona'}

# %% [markdown]
# In the previous exaple we have seen different things. First of all unlike with functions, in a class we do not define the attributes after their name (`class Person(name,age,city)`). We do it inside the constructor `__init__(self,name,age,city)`. Also, notice that when callig a class we create a new object, in this case `jhon` who has the properties of the parameters we introduce. If we would like to access those characteristics we can just type for example `jhon.name`. Notice that once we created the `jhon` object we can still change its parameter values:

# %%
jhon.age= 45
jhon.age
# Out:
# 45

# %% [markdown]
# The last important concept to be introduced inside our `class` are methods. Methods are functions inside a class, which are coded as normal `defs` and they support everything we've learned about functions. The peculiarity is that the first argument will recieve the `self` argument which will automatically pass all the variables that we have defined in `__init()__`. We can also include other variables that are method specific.

# %%
class Person:                # define the class
    
    def __init__(self,name,age,city):  # create the method that will define its attributes
        
        self.name = name               # set the class characteristics
        self.age = age
        self.city = city
        
    def sentence(self):
        print(f"Hi! My name is {self.name}, I'm {self.age} and I live in {self.city}")
        
    def check_city(self,newcity):
        
        if self.city == newcity:
            print('Wow! We are from the same city')
        else:
            print(f"Nice, I'm from {newcity}")
            
jhon = Person('Jhon',34,'Barcelona')    # we just need to provide the instance atributes

jhon.sentence()
jhon.check_city('London')
# Out:
# Hi! My name is Jhon, I'm 34 and I live in Barcelona
# Nice, I'm from London

# %% [markdown]
# Notice we could create another object with other instance attributes.

# %%
marta = Person('Marta',25,'Madrid')
marta.sentence()
# Out:
# Hi! My name is Marta, I'm 25 and I live in Madrid

# %% [markdown]
# #### Class Inheritance
#
# Besides serving as factories for generating multiple instance objects, classes also allow us to make changes by introducing new components (called subclasses) instad of changing existing components in place.  Python allows classes to inherit from other classes, opening the door to coding hierarchies of classes. The classes inherit from superclasses. Classes inherit all of the attribute names defined in their superclasess, and can also have attributes and methods of their own. Let's create a subclass from `Persons`.

# %%
# simple example
class Spanish(Person):
    pass

marta = Spanish('Marta',25,'Madrid')
marta.name
# Out:
# 'Marta'

# %% [markdown]
# The previous subclass is a very simple example, that adds nothing to the superclass `Person`. However, we could add new methods and even new instance attributes.

# %%
class Spanish(Person):
    
    def __init__(self,name,age,city,food):
        
        super().__init__(name,age,city)  # we are inheritng the isntance attributes from Person
        self.food = food
        
    def favfood(self):
        print(f'My favourite food is {self.food}')
        
pedro = Spanish('Pedro',34,'Madrid','paella')
pedro.sentence()          # we can call methods from Person
pedro.favfood()           # and also we can call methods from Spanish .
# Out:
# Hi! My name is Pedro, I'm 34 and I live in Madrid
# My favourite food is paella
